# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/maniram3112/stock-vs-crypto-risk-return-analysis/refs/heads/master/data/Raw_Data/raw_crypto.csv')

# %%
df.shape
# Out:
# (249825, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249825 entries, 0 to 249824
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    249825 non-null  object
#  1   BTC     249825 non-null  float64
#  2   ETH     249825 non-null  float64
#  3   XRP     249825 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 7.6+ MB

# %%
df.columns   # Bitcoin (BTC)  Ethereum (ETH) XRP (Ripple)
# Out:
# Index(['time', 'BTC', 'ETH', 'XRP'], dtype='object')

# %%
df.head()
# Out:
#          time      BTC     ETH     XRP
# 0  2020-04-02  6804.42  141.46  0.1785
# 1  2020-04-03  6743.68  141.48  0.1798
# 2  2020-04-03  6743.68  141.48  0.1798
# 3  2020-04-03  6743.68  141.48  0.1798
# 4  2020-04-03  6743.68  141.48  0.1798

# %%
df[df.duplicated()]
# Out:
#               time        BTC      ETH     XRP
# 2       2020-04-03    6743.68   141.48  0.1798
# 3       2020-04-03    6743.68   141.48  0.1798
# 4       2020-04-03    6743.68   141.48  0.1798
# 5       2020-04-03    6743.68   141.48  0.1798
# 6       2020-04-03    6743.68   141.48  0.1798
# ...            ...        ...      ...     ...
# 249819  2025-09-26  109723.94  4034.83  2.7850
# 249820  2025-09-26  109723.94  4034.83  2.7850
# 249821  2025-09-26  109723.94  4034.83  2.7850
# 249822  2025-09-26  109723.94  4034.83  2.7850
# 249823  2025-09-26  109723.94  4034.83  2.7850
#
# [247820 rows x 4 columns]

# %%
df.drop_duplicates( inplace=True,ignore_index=True)

# %%
df.shape
# Out:
# (2005, 4)

# %%
df.isna().sum()
# Out:
# time    0
# BTC     0
# ETH     0
# XRP     0
# dtype: int64

# %%
sdf = pd.read_csv(r'/content/stocks_wide.csv')

# %%
sdf.shape
# Out:
# (1299, 9)

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299 entries, 0 to 1298
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ticker       1299 non-null   object
#  1   AAPL         1256 non-null   float64
#  2   AMZN         1256 non-null   float64
#  3   GOOGL        1256 non-null   float64
#  4   INFY.NS      1239 non-null   float64
#  5   MSFT         1256 non-null   float64
#  6   RELIANCE.NS  1239 non-null   float64
#  7   TCS.NS       1239 non-null   float64
#  8   TSLA         1256 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 91.5+ KB

# %%
sdf.head()
# Out:
#        Ticker        AAPL        AMZN      GOOGL     INFY.NS        MSFT  \
# 0  28-09-2020  111.823631  158.702499  72.433426  898.601807  200.816406
# 1  29-09-2020  110.977364  157.244003  72.798889  897.356628  198.726135
# 2  30-09-2020  112.650459  157.436493  72.778053  896.689575  201.669754
# 3  01-10-2020  113.603714  161.063004  73.885391  905.049500  203.712036
# 4  02-10-2020  109.936577  156.250000  72.281464         NaN  197.700211
#
#    RELIANCE.NS       TCS.NS        TSLA
# 0  1004.917053  2256.142334  140.399994
# 1  1017.975891  2313.887695  139.690002
# 2  1013.124146  2317.514160  143.003326
# 3  1008.997925  2346.479248  149.386673
# 4          NaN          NaN  138.363327

# %%
sdf[sdf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ticker, AAPL, AMZN, GOOGL, INFY.NS, MSFT, RELIANCE.NS, TCS.NS, TSLA]
# Index: []

# %%
sdf.isna().sum()
# Out:
# Ticker          0
# AAPL           43
# AMZN           43
# GOOGL          43
# INFY.NS        60
# MSFT           43
# RELIANCE.NS    60
# TCS.NS         60
# TSLA           43
# dtype: int64

# %%
sdf.ffill(inplace=True)

# %%
sdf
# Out:
#           Ticker        AAPL        AMZN       GOOGL      INFY.NS        MSFT  \
# 0     28-09-2020  111.823631  158.702499   72.433426   898.601807  200.816406
# 1     29-09-2020  110.977364  157.244003   72.798889   897.356628  198.726135
# 2     30-09-2020  112.650459  157.436493   72.778053   896.689575  201.669754
# 3     01-10-2020  113.603714  161.063004   73.885391   905.049500  203.712036
# 4     02-10-2020  109.936577  156.250000   72.281464   905.049500  197.700211
# ...          ...         ...         ...         ...          ...         ...
# 1294  22-09-2025  256.079987  227.630005  252.529999  1499.500000  514.450012
# 1295  23-09-2025  254.429993  220.710007  251.660004  1497.500000  509.230011
# 1296  24-09-2025  252.309998  220.210007  247.139999  1494.599976  510.149994
# 1297  25-09-2025  256.869995  218.149994  245.789993  1484.800049  507.029999
# 1298  26-09-2025  255.460007  219.779999  246.539993  1448.900024  511.459992
#
# ...

# %%
sdf.isna().sum()
# Out:
# Ticker         0
# AAPL           0
# AMZN           0
# GOOGL          0
# INFY.NS        0
# MSFT           0
# RELIANCE.NS    0
# TCS.NS         0
# TSLA           0
# dtype: int64

# %%
out=pd.concat((sdf['Ticker'],round(sdf.iloc[:,1:],4)), axis = 1)

# %%
out
# Out:
#           Ticker      AAPL      AMZN     GOOGL    INFY.NS      MSFT  \
# 0     28-09-2020  111.8236  158.7025   72.4334   898.6018  200.8164
# 1     29-09-2020  110.9774  157.2440   72.7989   897.3566  198.7261
# 2     30-09-2020  112.6505  157.4365   72.7781   896.6896  201.6698
# 3     01-10-2020  113.6037  161.0630   73.8854   905.0495  203.7120
# 4     02-10-2020  109.9366  156.2500   72.2815   905.0495  197.7002
# ...          ...       ...       ...       ...        ...       ...
# 1294  22-09-2025  256.0800  227.6300  252.5300  1499.5000  514.4500
# 1295  23-09-2025  254.4300  220.7100  251.6600  1497.5000  509.2300
# 1296  24-09-2025  252.3100  220.2100  247.1400  1494.6000  510.1500
# 1297  25-09-2025  256.8700  218.1500  245.7900  1484.8000  507.0300
# 1298  26-09-2025  255.4600  219.7800  246.5400  1448.9000  511.4600
#
#       RELIANCE.NS     TCS.NS      TSLA
# 0       1004.9171  2256.1423  140.4000
# 1       1017.9759  2313.8877  139.6900
# ...

# %%
out.to_csv('stock.csv',index=False)

# %%
from google.colab import files
files.download("stock.csv")
